# %% [markdown]
# ## 2. Variables:
# - It is a name that refers to a value or object.
# - a lable attached to some data.
# - variable can store many types of data type eg string, int, float, dict, list etc

# %%
# name <------ Ajab
name = "Ajab"
# age <------ 351
age = 35
# hieght <------ 5'11
hieght = 5.11

print(f"My name is {name}, age {age} and my hieght is {hieght} feet.")
# Out:
# My name is Ajab, age 35 and my hieght is 5.11 feet.

# %%
# variable of different data type
print(type(name))
print(type(age))
print(type(hieght))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
